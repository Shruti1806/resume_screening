# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('UpdatedResumeDataSet.csv')
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
category = df['Category'].value_counts().reset_index()
category
# Out:
#                      Category  count
# 0              Java Developer     84
# 1                     Testing     70
# 2             DevOps Engineer     55
# 3            Python Developer     48
# 4               Web Designing     45
# 5                          HR     44
# 6                      Hadoop     42
# 7                  Blockchain     40
# 8               ETL Developer     40
# 9          Operations Manager     40
# 10               Data Science     40
# 11                      Sales     40
# 12        Mechanical Engineer     40
# 13                       Arts     36
# 14                   Database     33
# 15     Electrical Engineering     30
# 16         Health and fitness     30
# 17                        PMO     30
# 18           Business Analyst     28
# 19           DotNet Developer     28
# 20         Automation Testing     26
# 21  Network Security Engineer     25
# 22              SAP Developer     24
# 23             Civil Engineer     24
# 24                   Advocate     20

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=category['count'], y=category['Category'], palette='cool')
plt.title('Category Distribution through bargraph showing all the fields')
plt.xlabel('Category')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.show()

# %%
def cleanResume(resumeText):
    resumeText = re.sub('http\S+\s*', ' ', resumeText)  # remove URLs
    resumeText = re.sub('RT|cc', ' ', resumeText)  # remove RT and cc
    resumeText = re.sub('#\S+', '', resumeText)  # remove hashtags
    resumeText = re.sub('@\S+', '  ', resumeText)  # remove mentions
    resumeText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', resumeText)  # remove punctuations
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText)
    resumeText = re.sub('\s+', ' ', resumeText)  # remove extra whitespace
    return resumeText

# %%
df['cleaned'] = df['Resume'].apply(lambda x:cleanResume(x))
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                              cleaned
# 0  Skills Programming Languages Python pandas num...
# 1  Education Details May 2013 to May 2017 B E UIT...
# 2  Areas of Interest Deep Learning Control System...
# 3  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4  Education Details MCA YMCAUST Faridabad Haryan...

# %%
#getting the entire resume text
corpus=" "
for i in range(0,len(df)):
    corpus= corpus+ df["cleaned"][i]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
import string
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
tokenizer = nltk.tokenize.RegexpTokenizer('\w+')
#Tokenizing the text
tokens = tokenizer.tokenize(corpus)
len(tokens)


#now we shall make everything lowercase for uniformity
#to hold the new lower case words
words = []
# Looping through the tokens and make them lower case
for word in tokens:
    words.append(word.lower())
words[0:5]
# Out:
# ['skills', 'programming', 'languages', 'python', 'pandas']

# %%
# Now encode the data
label = LabelEncoder()
df['new_Category'] = label.fit_transform(df['Category'])
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                              cleaned  new_Category
# 0  Skills Programming Languages Python pandas num...             6
# 1  Education Details May 2013 to May 2017 B E UIT...             6
# 2  Areas of Interest Deep Learning Control System...             6
# 3  Skills R Python SAP HANA Tableau SAP HANA SQL ...             6
# 4  Education Details MCA YMCAUST Faridabad Haryan...             6

# %%
plt.hist(df['new_Category'])
plt.title('Category Distribution through histogram')
plt.show()

# %%
# Vectorizing the cleaned columns
text = df['cleaned'].values

target = df['new_Category'].values
word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    stop_words='english',
    max_features=1500)
word_vectorizer.fit(text)
WordFeatures = word_vectorizer.transform(text)
WordFeatures.shape
# Out:
# (962, 1500)

# %%
# Separate train and test data
X_train, X_test, y_train, y_test = train_test_split(WordFeatures, target, random_state=24, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((769, 1500), (193, 1500), (769,), (193,))

# %%
# Model Training
model = OneVsRestClassifier(KNeighborsClassifier())
model.fit(X_train, y_train)
# Prediction
y_pred = model.predict(X_test)

# %%
print(f'---------------------------------\n| Training Accuracy   :- {(model.score(X_train, y_train)*100).round(2)}% |')
print(f'---------------------------------\n| Validation Accuracy :- {(model.score(X_test, y_test)*100).round(2)}% |\n---------------------------------')
# Out:
# ---------------------------------
# | Training Accuracy   :- 98.96% |
# ---------------------------------
# | Validation Accuracy :- 96.89% |
# ---------------------------------

# %%
print(metrics.classification_report(y_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         9
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         7
#            7       1.00      1.00      1.00         6
#            8       1.00      1.00      1.00        10
#            9       1.00      1.00      1.00         6
#           10       1.00      1.00      1.00        10
#           11       1.00      1.00      1.00         8
#           12       1.00      1.00      1.00         6
#           13       1.00      1.00      1.00         6
#           14       1.00      1.00      1.00         8
#           15       1.00      1.00      1.00        16
#           16       1.00      1.00      1.00         7
#           17       1.00      1.00      1.00         6
#           18       1.00      1.00      1.00         8
#           19       1.00      1.00      1.00         8
#           20       1.00      1.00      1.00        11
#           21       1.00      1.00      1.00         4
#           22       1.00      1.00      1.00         9
#           23       1.00      1.00      1.00        13
#           24       1.00      1.00      1.00        10
#
#     accuracy                           1.00       193
#    macro avg       1.00      1.00      1.00       193
# weighted avg       1.00      1.00      1.00       193

# %%
#Stop words are generally the most common words in a language.
#English stop words from nltk.
stopwords = nltk.corpus.stopwords.words('english')
words_new = []
#Now we need to remove the stop words from the words variable
#Appending to words_new all words that are in words but not in sw
for word in words:
    if word not in stopwords:
        words_new.append(word)
words_new[0:5]
# Out:
# ['skills', 'programming', 'languages', 'python', 'pandas']

# %%
import nltk
nltk.download('omw-1.4')
# Perform Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wn = WordNetLemmatizer()
lem_words=[]
for word in words_new:
    word=wn.lemmatize(word)
    lem_words.append(word)
lem_words[0:5]
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['skill', 'programming', 'language', 'python', 'panda']

# %%
same=0
diff=0
for i in range(0,1832):
    if(lem_words[i]==words_new[i]):
        same=same+1
    elif(lem_words[i]!=words_new[i]):
        diff=diff+1
print('Number of words Lemmatized=', diff)
print('Number of words not Lemmatized=', same)
# Out:
# Number of words Lemmatized= 294
# Number of words not Lemmatized= 1538

# %%
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
total_words = 1832  # Replace with the total number of words
lemmatized_count = diff
not_lemmatized_count = same

# Creating a bar graph
categories = ['Lemmatized', 'Not Lemmatized']
counts = [lemmatized_count, not_lemmatized_count]

plt.figure(figsize=(8, 5))
plt.bar(categories, counts, color=['green', 'red'])
plt.xlabel('Lemmatization')
plt.ylabel('Number of Words')
plt.title('Number of Lemmatized and Not Lemmatized Words')
plt.show()

# %%
#The frequency distribution of the words
freq_dist = nltk.FreqDist(lem_words)
#Frequency Distribution Plot
plt.subplots(figsize=(20,12))
plt.title('Frequency distribution using line graph of counts and samples')
freq_dist.plot(30)
# Out:
# <Axes: title={'center': 'Frequency distribution using line graph of counts and samples'}, xlabel='Samples', ylabel='Counts'>

# %%
# Now we generate wordcloud
res=' '.join([i for i in lem_words if not i.isdigit()])

# %%
plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud)
plt.title('Resume Text WordCloud (100 Words)')
plt.axis('off')
plt.show()

# %%
plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=200,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud)
plt.title('Resume Text WordCloud (200 Words)')
plt.axis('off')
plt.show()
